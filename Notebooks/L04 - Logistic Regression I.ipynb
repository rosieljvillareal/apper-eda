# %%
#importing all the modules required
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

import warnings

warnings.filterwarnings(action="ignore")

# %%
df =  pd.read_csv('data/Pokemon.csv')

# %%
df.shape
# Out:
# (721, 23)

# %%
df.dtypes
# Out:
# Number                int64
# Name                 object
# Type_1               object
# Type_2               object
# Total                 int64
# HP                    int64
# Attack                int64
# Defense               int64
# Sp_Atk                int64
# Sp_Def                int64
# Speed                 int64
# Generation            int64
# isLegendary            bool
# Color                object
# hasGender              bool
# Pr_Male             float64
# Egg_Group_1          object
# Egg_Group_2          object
# hasMegaEvolution       bool
# Height_m            float64
# Weight_kg           float64
# Catch_Rate            int64
# Body_Style           object
# dtype: object

# %%
df
# Out:
#      Number        Name   Type_1  Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 0         1   Bulbasaur    Grass  Poison    318   45      49       49      65
# 1         2     Ivysaur    Grass  Poison    405   60      62       63      80
# 2         3    Venusaur    Grass  Poison    525   80      82       83     100
# 3         4  Charmander     Fire     NaN    309   39      52       43      60
# 4         5  Charmeleon     Fire     NaN    405   58      64       58      80
# ..      ...         ...      ...     ...    ...  ...     ...      ...     ...
# 716     717     Yveltal     Dark  Flying    680  126     131       95     131
# 717     718     Zygarde   Dragon  Ground    600  108     100      121      81
# 718     719     Diancie     Rock   Fairy    600   50     100      150     100
# 719     720       Hoopa  Psychic   Ghost    600   80     110       60     150
# 720     721   Volcanion     Fire   Water    600   80     110      120     130
#
#      Sp_Def  ...   Color  hasGender  Pr_Male   Egg_Group_1  Egg_Group_2  \
# 0        65  ...   Green       True    0.875       Monster        Grass
# 1        80  ...   Green       True    0.875       Monster        Grass
# 2       100  ...   Green       True    0.875       Monster        Grass
# 3        50  ...     Red       True    0.875       Monster       Dragon
# 4        65  ...     Red       True    0.875       Monster       Dragon
# ..      ...  ...     ...        ...      ...           ...          ...
# 716      98  ...     Red      False      NaN  Undiscovered          NaN
# 717      95  ...   Green      False      NaN  Undiscovered          NaN
# 718     150  ...    Pink      False      NaN  Undiscovered          NaN
# 719     130  ...  Purple      False      NaN  Undiscovered          NaN
# 720      90  ...   Brown      False      NaN  Undiscovered          NaN
#
#      hasMegaEvolution Height_m Weight_kg  Catch_Rate       Body_Style
# 0               False     0.71       6.9          45        quadruped
# 1               False     0.99      13.0          45        quadruped
# 2                True     2.01     100.0          45        quadruped
# 3               False     0.61       8.5          45   bipedal_tailed
# 4               False     1.09      19.0          45   bipedal_tailed
# ..                ...      ...       ...         ...              ...
# 716             False     5.79     203.0          45        two_wings
# 717             False     5.00     305.0           3  serpentine_body
# 718              True     0.71       8.8           3        head_arms
# 719             False     0.51       9.0           3        head_only
# 720             False     1.70     195.0           3        quadruped
#
# [721 rows x 23 columns]

# %%
df.describe()
# Out:
#           Number       Total          HP      Attack     Defense      Sp_Atk  \
# count  721.00000  721.000000  721.000000  721.000000  721.000000  721.000000
# mean   361.00000  417.945908   68.380028   75.013870   70.808599   68.737864
# std    208.27906  109.663671   25.848272   28.984475   29.296558   28.788005
# min      1.00000  180.000000    1.000000    5.000000    5.000000   10.000000
# 25%    181.00000  320.000000   50.000000   53.000000   50.000000   45.000000
# 50%    361.00000  424.000000   65.000000   74.000000   65.000000   65.000000
# 75%    541.00000  499.000000   80.000000   95.000000   85.000000   90.000000
# max    721.00000  720.000000  255.000000  165.000000  230.000000  154.000000
#
#            Sp_Def       Speed  Generation     Pr_Male    Height_m   Weight_kg  \
# count  721.000000  721.000000  721.000000  644.000000  721.000000  721.000000
# mean    69.291262   65.714286    3.323162    0.553377    1.144979   56.773370
# std     27.015860   27.277920    1.669873    0.199969    1.044369   89.095667
# min     20.000000    5.000000    1.000000    0.000000    0.100000    0.100000
# 25%     50.000000   45.000000    2.000000    0.500000    0.610000    9.400000
# 50%     65.000000   65.000000    3.000000    0.500000    0.990000   28.000000
# 75%     85.000000   85.000000    5.000000    0.500000    1.400000   61.000000
# max    230.000000  160.000000    6.000000    1.000000   14.500000  950.000000
#
#        Catch_Rate
# count  721.000000
# mean   100.246879
# std     76.573513
# min      3.000000
# 25%     45.000000
# 50%     65.000000
# 75%    180.000000
# max    255.000000

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,8))

sns.FacetGrid(df, hue="isLegendary", size = 10).map(plt.scatter, "Attack", "Defense").add_legend()

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,8))

sns.FacetGrid(df, hue="isLegendary", size = 10).map(plt.scatter, "Sp_Atk", "Sp_Def").add_legend()

# %%
# df = df.set_index('Name')
df2 = df[(df['Type_1']=='Fire')]
df2 = df2.drop('Generation', axis=1)
print("Fire Pokemon with Max HP:",df2.loc[df2['HP'].idxmax()]['Name'])
print("Fire Pokemon with Max SPEED:", df2.loc[df2['Speed'].idxmax()]['Name'])
print("Fire Pokemon with Max Sp.Attack:", df2.loc[df2['Sp_Atk'].idxmax()]['Name'])
print("Fire Pokemon with Max Sp.Defense:", df.loc[df2['Sp_Def'].idxmax()]['Name'])
print("Fire Pokemon with Max Attack:", df2.loc[df2['Attack'].idxmax()]['Name'])
print("Fire Pokemon with Max Defense:", df2.loc[df2['Defense'].idxmax()]['Name'])
# Out:
# Fire Pokemon with Max HP: Entei
# Fire Pokemon with Max SPEED: Talonflame
# Fire Pokemon with Max Sp.Attack: Heatran
# Fire Pokemon with Max Sp.Defense: Ho-Oh
# Fire Pokemon with Max Attack: Darmanitan
# Fire Pokemon with Max Defense: Torkoal

# %%
plt.figure(figsize=(18,8))

df3 = df[(df['Type_1']=='Fire')]#selecting fire type 
df3 = df3[["Attack", "Defense", "Sp_Atk", "Sp_Def", "Speed", "Weight_kg", "Height_m"]]
sns.boxplot(data = df3)
# Out:
# <AxesSubplot:>

# %%
plt.subplots(figsize = (18,5))
sns.boxplot(x="Type_1", y="Attack", data=df)
# Out:
# <AxesSubplot:xlabel='Type_1', ylabel='Attack'>

# %%
plt.subplots(figsize = (18,5))
sns.boxplot(x="Type_1", y="Defense", data=df)
# Out:
# <AxesSubplot:xlabel='Type_1', ylabel='Defense'>

# %%
df.pivot_table(values='isLegendary',index=['Generation'],aggfunc=np.sum).reset_index()
# Out:
#    Generation  isLegendary
# 0           1            4
# 1           2            5
# 2           3           10
# 3           4           11
# 4           5           10
# 5           6            6

# %% [markdown]
# Dataset is highly imabalanced with only a few legendary pokemons, just 6% of the data.

# %%
# plt.subplots(figsize = (18,5))
sns.heatmap(df[["Attack", "Defense", "Sp_Atk", "Sp_Def", "Speed", "Weight_kg"]].corr())
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
X = df[["Attack", "Defense", "Sp_Atk", "Sp_Def", "Speed", "Weight_kg", "Height_m"]]
logistic_model = LogisticRegression(class_weight="balanced")
logistic_model.fit(X, df["isLegendary"])
predictions = logistic_model.predict(X)
accuracy = metrics.accuracy_score(predictions,df["isLegendary"])
print(accuracy)
# Out:
# 0.9750346740638003

# %%
logistic_model.coef_
# Out:
# array([[0.1021556 , 0.1283165 , 0.11887944, 0.12336869, 0.17225544,
#         0.00825805, 0.18392761]])

# %%
df["pred"] = predictions
prob =[x[1] for x in logistic_model.predict_proba(X)]

df["prob"] = prob
selection = df[["Name","isLegendary","pred", "prob"]]
selection[selection["isLegendary"] == True].head()
# Out:
#          Name  isLegendary  pred      prob
# 143  Articuno         True  True  0.862581
# 144    Zapdos         True  True  0.901475
# 145   Moltres         True  True  0.842106
# 149    Mewtwo         True  True  0.999999
# 242    Raikou         True  True  0.984343

# %%
from sklearn.model_selection import train_test_split

X = df[["Attack", "Defense", "Sp_Atk", "Sp_Def", "Speed", "Weight_kg", "Height_m"]]

X_train, X_test, Y_train, Y_test = train_test_split(X, 
                   df["isLegendary"], 
                   train_size=0.55,    
                   random_state=42)


logistic_model = LogisticRegression()
logistic_model.fit(X_train, Y_train)
pred_train = logistic_model.predict(X_train)
pred_test =  logistic_model.predict(X_test)
train_accuracy = metrics.accuracy_score(pred_train,Y_train)
test_accuracy = metrics.accuracy_score(pred_test,Y_test)

# %%
train_accuracy
# Out:
# 0.9747474747474747

# %%
test_accuracy
# Out:
# 0.9692307692307692

# %%
print("Accuracy:",metrics.accuracy_score(Y_test, pred_test))
print("Precision:",metrics.precision_score(Y_test, pred_test))
print("Recall:",metrics.recall_score(Y_test, pred_test))
# Out:
# Accuracy: 0.9692307692307692
# Precision: 0.7647058823529411
# Recall: 0.6842105263157895

# %% [markdown]
# ### Note
#
# Precision: Precision is about being precise, i.e., how accurate your model is. In other words, you can say, when a model makes a prediction, how often it is correct. In your prediction case, when your Logistic Regression model predicted Pokemon are Legendary, the Pokemon are actually Legendary 40% of the time.
#
# Recall: If there are pokemon who are Legendary in the test set and your Logistic Regression model can identify it 100% of the time.

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(Y_train, pred_train)
cnf_matrix
# Out:
# array([[366,   3],
#        [  7,  20]], dtype=int64)

# %%
class_names=["0","1"] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
data = df
def updateTypeColumn(dataframe, columnName, columnValue):
    for index, row in dataframe.iterrows():
        if row.Type_1 == columnValue:
            dataframe.loc[index, columnName] = 1
        else:
            dataframe.loc[index, columnName] = 0
            
updateTypeColumn(data, 'Type_1', 'Fire')
data['Type_1'] = data['Type_1'].apply(int) # Converts column to int

# %%
X.head()
# Out:
#    Attack  Defense  Sp_Atk  Sp_Def  Speed  Weight_kg  Height_m
# 0      49       49      65      65     45        6.9      0.71
# 1      62       63      80      80     60       13.0      0.99
# 2      82       83     100     100     80      100.0      2.01
# 3      52       43      60      50     65        8.5      0.61
# 4      64       58      80      65     80       19.0      1.09

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, 
                   data["isFire"], 
                   test_size=0.7,  
                   train_size=0.3,    
                   random_state=42)


logistic_model = LogisticRegression()
logistic_model.fit(X_train, Y_train)
pred_train = logistic_model.predict(X_train)
pred_test =  logistic_model.predict(X_test)
train_accuracy = metrics.accuracy_score(pred_train,Y_train)
test_accuracy = metrics.accuracy_score(pred_test,Y_test)

# %%
test_accuracy
# Out:
# 0.9267326732673268

# %%
data["isFire"] = data['Type_1'].apply(lambda x: True if x == 1 else False)

# %%
data[data["isFire"]==data["pred"]]
# Out:
#      level_0  index        Name  Number  Type_1  Type_2  Total   HP  Attack  \
# 0          0      0   Bulbasaur       1       0  Poison    318   45      49
# 1          1      1     Ivysaur       2       0  Poison    405   60      62
# 2          2      2    Venusaur       3       0  Poison    525   80      82
# 6          6      6    Squirtle       7       0     NaN    314   44      48
# 7          7      7   Wartortle       8       0     NaN    405   59      63
# 8          8      8   Blastoise       9       0     NaN    530   79      83
# 9          9      9    Caterpie      10       0     NaN    195   45      30
# 10        10     10     Metapod      11       0     NaN    205   50      20
# 11        11     11  Butterfree      12       0  Flying    395   60      45
# 12        12     12      Weedle      13       0  Poison    195   40      35
# 13        13     13      Kakuna      14       0  Poison    205   45      25
# 14        14     14    Beedrill      15       0  Poison    395   65      90
# 15        15     15      Pidgey      16       0  Flying    251   40      45
# 16        16     16   Pidgeotto      17       0  Flying    349   63      60
# 17        17     17     Pidgeot      18       0  Flying    479   83      80
# 18        18     18     Rattata      19       0     NaN    253   30      56
# 19        19     19    Raticate      20       0     NaN    413   55      81
# 20        20     20     Spearow      21       0  Flying    262   40      60
# 21        21     21      Fearow      22       0  Flying    442   65      90
# 22        22     22       Ekans      23       0     NaN    288   35      60
# 23        23     23       Arbok      24       0     NaN    438   60      85
# 24        24     24     Pikachu      25       0     NaN    320   35      55
# 25        25     25      Raichu      26       0     NaN    485   60      90
# 26        26     26   Sandshrew      27       0     NaN    300   50      75
# 27        27     27   Sandslash      28       0     NaN    450   75     100
# 28        28     28    Nidoran♀      29       0     NaN    275   55      47
# 29        29     29    Nidorina      30       0     NaN    365   70      62
# 30        30     30   Nidoqueen      31       0  Ground    505   90      92
# 31        31     31    Nidoran♂      32       0     NaN    273   46      57
# 32        32     32    Nidorino      33       0     NaN    365   61      72
# ..       ...    ...         ...     ...     ...     ...    ...  ...     ...
# 690      690    690    Dragalge     691       0  Dragon    494   65      75
# 691      691    691   Clauncher     692       0     NaN    330   50      53
# 692      692    692   Clawitzer     693       0     NaN    500   71      73
# 693      693    693  Helioptile     694       0  Normal    289   44      38
# 694      694    694   Heliolisk     695       0  Normal    481   62      55
# 695      695    695      Tyrunt     696       0  Dragon    362   58      89
# 696      696    696   Tyrantrum     697       0  Dragon    521   82     121
# 697      697    697      Amaura     698       0     Ice    362   77      59
# 698      698    698     Aurorus     699       0     Ice    521  123      77
# 699      699    699     Sylveon     700       0     NaN    525   95      65
# 700      700    700    Hawlucha     701       0  Flying    500   78      92
# 701      701    701     Dedenne     702       0   Fairy    431   67      58
# 702      702    702     Carbink     703       0   Fairy    500   50      50
# 703      703    703       Goomy     704       0     NaN    300   45      50
# 704      704    704     Sliggoo     705       0     NaN    452   68      75
# 705      705    705      Goodra     706       0     NaN    600   90     100
# 706      706    706      Klefki     707       0   Fairy    470   57      80
# 707      707    707    Phantump     708       0   Grass    309   43      70
# 708      708    708   Trevenant     709       0   Grass    474   85     110
# 709      709    709   Pumpkaboo     710       0   Grass    335   49      66
# 710      710    710   Gourgeist     711       0   Grass    494   65      90
# 711      711    711    Bergmite     712       0     NaN    304   55      69
# 712      712    712     Avalugg     713       0     NaN    514   95     117
# 713      713    713      Noibat     714       0  Dragon    245   40      30
# 714      714    714     Noivern     715       0  Dragon    535   85      70
# 715      715    715     Xerneas     716       0     NaN    680  126     131
# 716      716    716     Yveltal     717       0  Flying    680  126     131
# 717      717    717     Zygarde     718       0  Ground    600  108     100
# 718      718    718     Diancie     719       0   Fairy    600   50     100
# 719      719    719       Hoopa     720       0   Ghost    600   80     110
#
#      Defense  ...     Egg_Group_1  Egg_Group_2  hasMegaEvolution  Height_m  \
# 0         49  ...         Monster        Grass             False      0.71
# 1         63  ...         Monster        Grass             False      0.99
# 2         83  ...         Monster        Grass              True      2.01
# 6         65  ...         Monster      Water_1             False      0.51
# 7         80  ...         Monster      Water_1             False      0.99
# 8        100  ...         Monster      Water_1              True      1.60
# 9         35  ...             Bug          NaN             False      0.30
# 10        55  ...             Bug          NaN             False      0.71
# 11        50  ...             Bug          NaN             False      1.09
# 12        30  ...             Bug          NaN             False      0.30
# 13        50  ...             Bug          NaN             False      0.61
# 14        40  ...             Bug          NaN              True      0.99
# 15        40  ...          Flying          NaN             False      0.30
# 16        55  ...          Flying          NaN             False      1.09
# 17        75  ...          Flying          NaN              True      1.50
# 18        35  ...           Field          NaN             False      0.30
# 19        60  ...           Field          NaN             False      0.71
# 20        30  ...          Flying          NaN             False      0.30
# 21        65  ...          Flying          NaN             False      1.19
# 22        44  ...           Field       Dragon             False      2.01
# 23        69  ...           Field       Dragon             False      3.51
# 24        40  ...           Field        Fairy             False      0.41
# 25        55  ...           Field        Fairy             False      0.79
# 26        85  ...           Field          NaN             False      0.61
# 27       110  ...           Field          NaN             False      0.99
# 28        52  ...         Monster        Field             False      0.41
# 29        67  ...    Undiscovered          NaN             False      0.79
# 30        87  ...    Undiscovered          NaN             False      1.30
# 31        40  ...         Monster        Field             False      0.51
# 32        57  ...         Monster        Field             False      0.89
# ..       ...  ...             ...          ...               ...       ...
# 690       90  ...         Water_1       Dragon             False      1.80
# 691       62  ...         Water_1      Water_3             False      0.51
# 692       88  ...         Water_1      Water_3             False      1.30
# 693       33  ...         Monster       Dragon             False      0.51
# 694       52  ...         Monster       Dragon             False      0.99
# 695       77  ...         Monster       Dragon             False      0.79
# 696      119  ...         Monster       Dragon             False      2.49
# 697       50  ...         Monster          NaN             False      1.30
# 698       72  ...         Monster          NaN             False      2.69
# 699       65  ...           Field          NaN             False      0.99
# 700       75  ...      Human-Like          NaN             False      0.79
# 701       57  ...           Field        Fairy             False      0.20
# 702      150  ...           Fairy      Mineral             False      0.30
# 703       35  ...          Dragon          NaN             False      0.30
# 704       53  ...          Dragon          NaN             False      0.79
# 705       70  ...          Dragon          NaN             False      2.01
# 706       91  ...         Mineral          NaN             False      0.20
# 707       48  ...           Grass    Amorphous             False      0.41
# 708       76  ...           Grass    Amorphous             False      1.50
# 709       70  ...       Amorphous          NaN             False      0.41
# 710      122  ...       Amorphous          NaN             False      1.70
# 711       85  ...         Monster          NaN             False      0.99
# 712      184  ...         Monster          NaN             False      2.01
# 713       35  ...          Flying          NaN             False      0.51
# 714       80  ...          Flying          NaN             False      1.50
# 715       95  ...    Undiscovered          NaN             False      3.00
# 716       95  ...    Undiscovered          NaN             False      5.79
# 717      121  ...    Undiscovered          NaN             False      5.00
# 718      150  ...    Undiscovered          NaN              True      0.71
# 719       60  ...    Undiscovered          NaN             False      0.51
#
#      Weight_kg Catch_Rate        Body_Style   pred      prob isFire
# 0          6.9         45         quadruped  False  0.068975  False
# 1         13.0         45         quadruped  False  0.059815  False
# 2        100.0         45         quadruped  False  0.052080  False
# 6          9.0         45    bipedal_tailed  False  0.037242  False
# 7         22.5         45    bipedal_tailed  False  0.030370  False
# 8         85.5         45    bipedal_tailed  False  0.026424  False
# 9          2.9        255         insectoid  False  0.055280  False
# 10         9.9        120   serpentine_body  False  0.030548  False
# 11        32.0         45        four_wings  False  0.087736  False
# 12         3.2        255   serpentine_body  False  0.064391  False
# 13        10.0        120   serpentine_body  False  0.036912  False
# 14        29.5         45        four_wings  False  0.065000  False
# 15         1.8        255         two_wings  False  0.064677  False
# 16        30.0        120         two_wings  False  0.050914  False
# 17        39.5         45         two_wings  False  0.040612  False
# 18         3.5        255         quadruped  False  0.063613  False
# 19        18.5        127         quadruped  False  0.046648  False
# 20         2.0        255         two_wings  False  0.086349  False
# 21        38.0         90         two_wings  False  0.055744  False
# 22         6.9        255   serpentine_body  False  0.036135  False
# 23        65.0         90   serpentine_body  False  0.023448  False
# 24         6.0        190         quadruped  False  0.077267  False
# 25        30.0         75    bipedal_tailed  False  0.115257  False
# 26        12.0        255    bipedal_tailed  False  0.020742  False
# 27        29.5         90    bipedal_tailed  False  0.016889  False
# 28         7.0        235         quadruped  False  0.052773  False
# 29        20.0        120         quadruped  False  0.044949  False
# 30        60.0         45    bipedal_tailed  False  0.038785  False
# 31         9.0        235         quadruped  False  0.073064  False
# 32        19.5        120         quadruped  False  0.059055  False
# ..         ...        ...               ...    ...       ...    ...
# 690       81.5         55         head_base  False  0.033274  False
# 691        8.3        225         insectoid  False  0.049682  False
# 692       35.3         55   serpentine_body  False  0.074822  False
# 693        6.0        190    bipedal_tailed  False  0.104769  False
# 694       21.0         75    bipedal_tailed  False  0.109687  False
# 695       26.0         45    bipedal_tailed  False  0.040981  False
# 696      270.0         45    bipedal_tailed  False  0.036940  False
# 697       25.2         45         quadruped  False  0.068350  False
# 698      225.0         45         quadruped  False  0.086768  False
# 699       23.5         45         quadruped  False  0.070706  False
# 700       21.5        100  bipedal_tailless  False  0.060174  False
# 701        2.2        180    bipedal_tailed  False  0.089065  False
# 702        5.7         60         head_only  False  0.002094  False
# 703        2.8         45   serpentine_body  False  0.081000  False
# 704       17.5         45   serpentine_body  False  0.071365  False
# 705      150.5         45    bipedal_tailed  False  0.075264  False
# 706        3.0         75         head_only  False  0.040878  False
# 707        7.0        120         head_arms  False  0.071955  False
# 708       71.0         60     several_limbs  False  0.049210  False
# 709        5.0        120         head_only  False  0.037180  False
# 710       39.0         60         head_base  False  0.009896  False
# 711       99.5        190         quadruped  False  0.029761  False
# 712      505.0         55         quadruped  False  0.014067  False
# 713        8.0        190         two_wings  False  0.071981  False
# 714       85.0         45         two_wings  False  0.060028  False
# 715      215.0         45         quadruped  False  0.117514  False
# 716      203.0         45         two_wings  False  0.046642  False
# 717      305.0          3   serpentine_body  False  0.012575  False
# 718        8.8          3         head_arms  False  0.008561  False
# 719        9.0          3         head_only  False  0.254245  False
#
# [662 rows x 28 columns]

# %%
data["pred"] = pred
prob =[x[1] for x in lm.predict_proba(X)]

# data["prob"] = prob
# selection = data[["Name","isLegendary","pred", "prob"]]
# selection[selection["Type_1"] == True].head()

# %%
sel = data[["Name","Type_1","pred", "prob"]]
sel
# Out:
#            Name  Type_1   pred      prob
# 0     Bulbasaur       0  False  0.068975
# 1       Ivysaur       0  False  0.059815
# 2      Venusaur       0  False  0.052080
# 3    Charmander       1  False  0.084723
# 4    Charmeleon       1  False  0.075264
# 5     Charizard       1  False  0.085258
# 6      Squirtle       0  False  0.037242
# 7     Wartortle       0  False  0.030370
# 8     Blastoise       0  False  0.026424
# 9      Caterpie       0  False  0.055280
# 10      Metapod       0  False  0.030548
# 11   Butterfree       0  False  0.087736
# 12       Weedle       0  False  0.064391
# 13       Kakuna       0  False  0.036912
# 14     Beedrill       0  False  0.065000
# 15       Pidgey       0  False  0.064677
# 16    Pidgeotto       0  False  0.050914
# 17      Pidgeot       0  False  0.040612
# 18      Rattata       0  False  0.063613
# 19     Raticate       0  False  0.046648
# 20      Spearow       0  False  0.086349
# 21       Fearow       0  False  0.055744
# 22        Ekans       0  False  0.036135
# 23        Arbok       0  False  0.023448
# 24      Pikachu       0  False  0.077267
# 25       Raichu       0  False  0.115257
# 26    Sandshrew       0  False  0.020742
# 27    Sandslash       0  False  0.016889
# 28     Nidoran♀       0  False  0.052773
# 29     Nidorina       0  False  0.044949
# ..          ...     ...    ...       ...
# 691   Clauncher       0  False  0.049682
# 692   Clawitzer       0  False  0.074822
# 693  Helioptile       0  False  0.104769
# 694   Heliolisk       0  False  0.109687
# 695      Tyrunt       0  False  0.040981
# 696   Tyrantrum       0  False  0.036940
# 697      Amaura       0  False  0.068350
# 698     Aurorus       0  False  0.086768
# 699     Sylveon       0  False  0.070706
# 700    Hawlucha       0  False  0.060174
# 701     Dedenne       0  False  0.089065
# 702     Carbink       0  False  0.002094
# 703       Goomy       0  False  0.081000
# 704     Sliggoo       0  False  0.071365
# 705      Goodra       0  False  0.075264
# 706      Klefki       0  False  0.040878
# 707    Phantump       0  False  0.071955
# 708   Trevenant       0  False  0.049210
# 709   Pumpkaboo       0  False  0.037180
# 710   Gourgeist       0  False  0.009896
# 711    Bergmite       0  False  0.029761
# 712     Avalugg       0  False  0.014067
# 713      Noibat       0  False  0.071981
# 714     Noivern       0  False  0.060028
# 715     Xerneas       0  False  0.117514
# 716     Yveltal       0  False  0.046642
# 717     Zygarde       0  False  0.012575
# 718     Diancie       0  False  0.008561
# 719       Hoopa       0  False  0.254245
# 720   Volcanion       1  False  0.087111
#
# [721 rows x 4 columns]
